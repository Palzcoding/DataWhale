# %% [markdown]
# **复习**:这门课程得主要目的是通过真实的数据，以实战的方式了解数据分析的流程和熟悉数据分析python的基本操作。知道了课程的目的之后，我们接下来我们要正式的开始数据分析的实战教学，完成kaggle上[泰坦尼克的任务](https://www.kaggle.com/c/titanic/overview)，实战数据分析全流程。
# 这里有两份资料：
# 教材《Python for Data Analysis》和 baidu.com &
# google.com（善用搜索引擎）

# %% [markdown]
# ## 1 第一章：数据载入及初步观察

# %% [markdown]
# ### 1.1 载入数据
# 数据集下载 https://www.kaggle.com/c/titanic/overview

# %% [markdown]
# #### 1.1.1 任务一：导入numpy和pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 【提示】如果加载失败，学会如何在你的python环境下安装numpy和pandas这两个库

# %%
import os
os.getcwd()#写入代码
# Out:
# 'C:\\Users\\Lenovo\\Desktop\\datawhale\\1.1 Titanic'

# %% [markdown]
# #### 1.1.2 任务二：载入数据
# (1) 使用相对路径载入数据
# (2) 使用绝对路径载入数据

# %%
#写入代码
titanic = pd.read_csv(r'C:\Users\Lenovo\Desktop\datawhale\1.1 Titanic\test.csv') #absolute path，注意r因为‘’里的\会有歧义
titanic.head()
titanic1 = pd.read_table(r'test.csv',sep=',')
titanic1.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# 【提示】相对路径载入报错时，尝试使用os.getcwd()查看当前工作目录。
# 【思考】知道数据加载的方法后，试试pd.read_csv()和pd.read_table()的不同，如果想让他们效果一样，需要怎么做？了解一下'.tsv'和'.csv'的不同，如何加载这两个数据集？
# 【总结】加载的数据是所有工作的第一步，我们的工作会接触到不同的数据格式（eg:.csv;.tsv;.xlsx）,但是加载的方法和思路都是一样的，在以后工作和做项目的过程中，遇到之前没有碰到的问题，要多多查资料吗，使用googel，了解业务逻辑，明白输入和输出是什么。

# %% [markdown]
# #### 1.1.3 任务三：每1000行为一个数据模块，逐块读取

# %%
#写入代码
chunker = pd.read_csv('test.csv',chunksize=1000)
chunker
# Get the first chunk
first_chunk = next(chunker)

print(first_chunk.head())
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# 【思考】什么是逐块读取？为什么要逐块读取呢？
#
#
# 【提示】大家可以chunker(数据块)是什么类型？用`for`循环打印出来出处具体的样子是什么？

# %% [markdown]
# #### 1.1.4 任务四：将表头改成中文，索引改为乘客ID [对于某些英文资料，我们可以通过翻译来更直观的熟悉我们的数据]
# PassengerId => 乘客ID
# Survived    => 是否幸存
# Pclass      => 乘客等级(1/2/3等舱位)
# Name        => 乘客姓名
# Sex         => 性别
# Age         => 年龄
# SibSp       => 堂兄弟/妹个数
# Parch       => 父母与小孩个数
# Ticket      => 船票信息
# Fare        => 票价
# Cabin       => 客舱
# Embarked    => 登船港口

# %%
#Method 1
col_name = ['乘客ID','仓位等级','姓名','性别','年龄','兄弟姐妹个数','父母子女个数','船票信息','票价','客舱','登船港口']
titanic.columns = col_name
titanic.set_index('乘客ID',inplace=True)
titanic.head()
# Out:
#       仓位等级                                            姓名      性别    年龄  \
# 乘客ID
# 892      3                              Kelly, Mr. James    male  34.5
# 893      3              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 894      2                     Myles, Mr. Thomas Francis    male  62.0
# 895      3                              Wirz, Mr. Albert    male  27.0
# 896      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
#
#       兄弟姐妹个数  父母子女个数     船票信息       票价   客舱 登船港口
# 乘客ID
# 892        0       0   330911   7.8292  NaN    Q
# 893        1       0   363272   7.0000  NaN    S
# 894        0       0   240276   9.6875  NaN    Q
# 895        0       0   315154   8.6625  NaN    S
# 896        1       1  3101298  12.2875  NaN    S

# %%
#Method 2: 直接在read的时候就编辑
train = pd.read_csv('train.csv',names=['乘客ID','仓位等级','姓名','性别','年龄','兄弟姐妹个数','父母子女个数','船票信息','票价','客舱','登船港口'],header=0)
train.set_index('乘客ID',inplace=True)
train.head(5)

#train = pd.read_csv('train.csv', names=['乘客ID','仓位等级','姓名','性别','年龄','兄弟姐妹个数','父母子女个数','船票信息','票价','客舱','登船港口'],index_col='乘客ID',header=0)
# Out:
#       仓位等级                                                 姓名      性别    年龄  \
# 乘客ID
# 0        3                            Braund, Mr. Owen Harris    male  22.0
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 1        3                             Heikkinen, Miss. Laina  female  26.0
# 1        1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 0        3                           Allen, Mr. William Henry    male  35.0
#
#       兄弟姐妹个数  父母子女个数              船票信息       票价    客舱 登船港口
# 乘客ID
# 0          1       0         A/5 21171   7.2500   NaN    S
# 1          1       0          PC 17599  71.2833   C85    C
# 1          0       0  STON/O2. 3101282   7.9250   NaN    S
# 1          1       0            113803  53.1000  C123    S
# 0          0       0            373450   8.0500   NaN    S

# %% [markdown]
# 【思考】所谓将表头改为中文其中一个思路是：将英文列名表头替换成中文。还有其他的方法吗？

# %% [markdown]
# ### 1.2 初步观察
# 导入数据后，你可能要对数据的整体结构和样例进行概览，比如说，数据大小、有多少列，各列都是什么格式的，是否包含null等

# %% [markdown]
# #### 1.2.1 任务一：查看数据的基本信息

# %%
train.info()
train.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 0 to 0
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   仓位等级    891 non-null    int64
#  1   姓名      891 non-null    object
#  2   性别      891 non-null    object
#  3   年龄      714 non-null    float64
#  4   兄弟姐妹个数  891 non-null    int64
#  5   父母子女个数  891 non-null    int64
#  6   船票信息    891 non-null    object
#  7   票价      891 non-null    float64
#  8   客舱      204 non-null    object
#  9   登船港口    889 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 76.6+ KB
#              仓位等级          年龄      兄弟姐妹个数      父母子女个数          票价
# count  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.836071   14.526497    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# ...

# %% [markdown]
# 【提示】有多个函数可以这样做，你可以做一下总结

# %% [markdown]
# #### 1.2.2 任务二：观察表格前10行的数据和后15行的数据

# %%
train.head(10)
# Out:
#       仓位等级                                             姓名      性别    年龄  \
# 乘客ID
# 0        3                  Gustafsson, Mr. Alfred Ossian    male  20.0
# 0        3                           Petroff, Mr. Nedelio    male  19.0
# 0        3                             Laleff, Mr. Kristo    male   NaN
# 1        1  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 1        2   Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0
# 0        3                             Markun, Mr. Johann    male  33.0
# 0        3                   Dahlberg, Miss. Gerda Ulrika  female  22.0
# 0        2                  Banfield, Mr. Frederick James    male  28.0
# 0        3                         Sutehall, Mr. Henry Jr    male  25.0
# 0        3           Rice, Mrs. William (Margaret Norton)  female  39.0
# 0        2                          Montvila, Rev. Juozas    male  27.0
# 1        1                   Graham, Miss. Margaret Edith  female  19.0
# ...

# %%
train.tail(15)
# Out:
#       仓位等级                                             姓名      性别    年龄  \
# 乘客ID
# 0        3                  Gustafsson, Mr. Alfred Ossian    male  20.0
# 0        3                           Petroff, Mr. Nedelio    male  19.0
# 0        3                             Laleff, Mr. Kristo    male   NaN
# 1        1  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 1        2   Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0
# 0        3                             Markun, Mr. Johann    male  33.0
# 0        3                   Dahlberg, Miss. Gerda Ulrika  female  22.0
# 0        2                  Banfield, Mr. Frederick James    male  28.0
# 0        3                         Sutehall, Mr. Henry Jr    male  25.0
# 0        3           Rice, Mrs. William (Margaret Norton)  female  39.0
# 0        2                          Montvila, Rev. Juozas    male  27.0
# 1        1                   Graham, Miss. Margaret Edith  female  19.0
# ...

# %% [markdown]
# #### 1.2.4 任务三：判断数据是否为空，为空的地方返回True，其余地方返回False

# %%
#写入代码
train.isnull()
# Out:
#        仓位等级     姓名     性别     年龄  兄弟姐妹个数  父母子女个数   船票信息     票价     客舱   登船港口
# 乘客ID
# 0     False  False  False  False   False   False  False  False   True  False
# 1     False  False  False  False   False   False  False  False  False  False
# 1     False  False  False  False   False   False  False  False   True  False
# 1     False  False  False  False   False   False  False  False  False  False
# 0     False  False  False  False   False   False  False  False   True  False
# ...     ...    ...    ...    ...     ...     ...    ...    ...    ...    ...
# 0     False  False  False  False   False   False  False  False   True  False
# 1     False  False  False  False   False   False  False  False  False  False
# 0     False  False  False   True   False   False  False  False   True  False
# 1     False  False  False  False   False   False  False  False  False  False
# 0     False  False  False  False   False   False  False  False   True  False
#
# [891 rows x 10 columns]

# %% [markdown]
# 【总结】上面的操作都是数据分析中对于数据本身的观察

# %% [markdown]
# 【思考】对于一个数据，还可以从哪些方面来观察？找找答案，这个将对下面的数据分析有很大的帮助

# %% [markdown]
# ### 1.3 保存数据

# %% [markdown]
# #### 1.3.1 任务一：将你加载并做出改变的数据，在工作目录下保存为一个新文件train_chinese.csv

# %%
# 防止中文乱码，加入`encoding='utf_8_sig'
train.to_csv('train_chn1.csv',encoding='utf_8_sig')  
pd.read_csv('train_chn1.csv')
# Out:
#      乘客ID  仓位等级                                                 姓名      性别  \
# 0       0     3                            Braund, Mr. Owen Harris    male
# 1       1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2       1     3                             Heikkinen, Miss. Laina  female
# 3       1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4       0     3                           Allen, Mr. William Henry    male
# ..    ...   ...                                                ...     ...
# 886     0     2                              Montvila, Rev. Juozas    male
# 887     1     1                       Graham, Miss. Margaret Edith  female
# 888     0     3           Johnston, Miss. Catherine Helen "Carrie"  female
# 889     1     1                              Behr, Mr. Karl Howell    male
# 890     0     3                                Dooley, Mr. Patrick    male
#
#        年龄  兄弟姐妹个数  父母子女个数              船票信息       票价    客舱 登船港口
# ...

# %%
train.to_pickle(r'C:\Users\Lenovo\Desktop\datawhale\1.1 Titanic\train.pk1')

# %% [markdown]
# 【总结】数据的加载以及入门，接下来就要接触数据本身的运算，我们将主要掌握numpy和pandas在工作和项目场景的运用。

# %%
pd.read_pickle('train.pk1')
# Out:
#       仓位等级                                                 姓名      性别    年龄  \
# 乘客ID
# 0        3                            Braund, Mr. Owen Harris    male  22.0
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 1        3                             Heikkinen, Miss. Laina  female  26.0
# 1        1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 0        3                           Allen, Mr. William Henry    male  35.0
# ...    ...                                                ...     ...   ...
# 0        2                              Montvila, Rev. Juozas    male  27.0
# 1        1                       Graham, Miss. Margaret Edith  female  19.0
# 0        3           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 1        1                              Behr, Mr. Karl Howell    male  26.0
# 0        3                                Dooley, Mr. Patrick    male  32.0
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 pd.read_csv('train_chn.csv')
#
# File D:\python\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...
